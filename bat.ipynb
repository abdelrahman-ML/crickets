# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np

# %%
url='https://www.espncricinfo.com/ci/content/player/25056.html'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]

#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    
    name=t.text_content()
    print(name)
    col.append(name)
# Out:
# Mat
# Inns
# NO
# Runs
# HS
# Ave
# BF
# SR
# 100
# 50
# 4s
# 6s
# Ct
# St

# %%
#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# [15, 15, 15, 15, 15, 15, 14, 14, 14, 14, 14, 14]

# %%
col[0]='sort'

df_Batting=pd.DataFrame(columns=col)

# %%
df_Batting
# Out:
# Empty DataFrame
# Columns: [sort, Mat, Inns, NO, Runs, HS, Ave, BF, SR, 100, 50, 4s, 6s, Ct, St]
# Index: []

# %%
def get_data( url ):
    url=url
    page = requests.get(url)
    doc = lh.fromstring(page.content)
    tr_elements = doc.xpath('//tr')
    raw=[]
    for j in range(1,len(tr_elements)):
        T=tr_elements[j]
  
        if (len(T)==14)  :
          break  
        elif (len(T)==15)  :
            for t in T.iterchildren():
                data=str(t.text_content())
                raw.append(data)
    arr = np.array(raw)
    n_raw=int(arr.shape[0]/15)
    arr=arr.reshape(n_raw,15)
    Bat=pd.DataFrame(data=arr,columns=col)
    for i in Bat['sort'].values:
        if i =='ODIs':
             Bat= Bat.set_index([Bat.columns[0]])
             global df_Batting
             df_Batting=df_Batting.append(Bat.loc['ODIs'])
        else:
            continue
    #df_Batting=df_Batting.drop(df_Batting.columns[0],axis=1)

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

countries={'1':'england','2':'australia','3':'southafrica','4':'westindies','5':'newzealand','6':'india','7':'pakistan','8':'srilanka','9':'zimbabwe','11':'usa','12':'Bermuda','14':'East and Central Africa','15':'Netherlands','17':'Canada','19':'Hong Kong','20':' Papua New Guinea','25':'Bangladesh','26':' Kenya','27':'United Arab Emirates','28':'Namibia','29':'Ireland','30':'Scotland','32':'Nepal','37':'Oman','40':'Afghanistan'}
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
li=[]
for key,value in countries.items():
 url = 'https://www.espncricinfo.com/ci/content/player/index.html?country='+key
 html = urlopen(url, context=ctx).read()
 soup = BeautifulSoup(html, "html.parser")

# Retrieve all of the anchor tags
 tags = soup('a')
 count=0

 for tag in tags:
     tag1 =tag.get('href', None).split('.')
     tag2=tag1[0].split('/')
     for i in tag2:
            if i.isdigit()==True:
                li.append('https://www.espncricinfo.com/'+value+'/content/player/'+i+'.html') 



li = list(set(li)) 
print(li)
# Out:
# ['https://www.espncricinfo.com/Nepal/content/player/1141934.html', 'https://www.espncricinfo.com/usa/content/player/953793.html', 'https://www.espncricinfo.com/srilanka/content/player/370040.html', 'https://www.espncricinfo.com/Ireland/content/player/364343.html', 'https://www.espncricinfo.com/Nepal/content/player/446812.html', 'https://www.espncricinfo.com/Netherlands/content/player/960035.html', 'https://www.espncricinfo.com/United Arab Emirates/content/player/156066.html', 'https://www.espncricinfo.com/Canada/content/player/817069.html', 'https://www.espncricinfo.com/zimbabwe/content/player/571703.html', 'https://www.espncricinfo.com/india/content/player/234675.html', 'https://www.espncricinfo.com/ Kenya/content/player/156066.html', 'https://www.espncricinfo.com/england/content/player/247235.html', 'https://www.espncricinfo.com/england/content/player/288992.html', 'https://www.espncricinfo.com/newzealand/content/player/388802.html', 'https://www.espncricinfo.com/Scotland/content/player/156066.html', 'https://www.espncricinfo.com/Scotland/content/player/526492.html', 'https://www.espncricinfo.com/srilanka/content/player/49700.html', 'https://www.espncricinfo.com/newzealand/content/player/232359.html', 'https://www.espncricinfo.com/pakistan/content/player/43685.html', 'https://www.espncricinfo.com/pakistan/content/player/556684.html', 'https://www.espncricinfo.com/Netherlands/content/player/233712.html', 'https://www.espncricinfo.com/westindies/content/player/604302.html', 'https://www.espncricinfo.com/zimbabwe/content/player/55608.html', 'https://www.espncricinfo.com/Ireland/content/player/414821.html', 'https://www.espncricinfo.com/Afghanistan/content/player/440963.html', 'https://www.espncricinfo.com/Bermuda/content/player/307528.html', 'https://www.espncricinfo.com/United Arab Emirates/content/player/281653.html', 'https://www.espncricinfo.com/Nepal/content/player/25955.html', 'https://www.espncricinfo.com/southafrica/content/player/486672.html', 'https://www.espncricinfo.com/india/content/player/326017.html', 'https://www.espncricinfo.com/Bangladesh/content/player/300619.html', 'https://www.espncricinfo.com/usa/content/player/25643.html', 'https://www.espncricinfo.com/india/content/player/452044.html', 'https://www.espncricinfo.com/india/content/player/422108.html', 'https://www.espncricinfo.com/Hong Kong/content/player/208253.html', 'https://www.espncricinfo.com/Afghanistan/content/player/320652.html', 'https://www.espncricinfo.com/Scotland/content/player/509107.html', 'https://www.espncricinfo.com/england/content/player/653695.html', 'https://www.espncricinfo.com/usa/content/player/957645.html', 'https://www.espncricinfo.com/australia/content/player/489889.html', 'https://www.espncricinfo.com/zimbabwe/content/player/232442.html', 'https://www.espncricinfo.com/Namibia/content/player/1069820.html', 'https://www.espncricinfo.com/Bermuda/content/player/679551.html', 'https://www.espncricinfo.com/Afghanistan/content/player/633362.html', 'https://www.espncricinfo.com/ Papua New Guinea/content/player/440990.html', 'https://www.espncricinfo.com/ Papua New Guinea/content/player/646175.html', 'https://www.espncricinfo.com/Hong Kong/content/player/156066.html', 'https://www.espncricinfo.com/ Papua New Guinea/content/player/646193.html', 'https://www.espncricinfo.com/Bangladesh/content/player/629058.html', 'https://www.espncricinfo.com/Netherlands/content/player/470699.html', 'https://www.espncricinfo.com/pakistan/content/player/288211.html', 'https://www.espncricinfo.com/Canada/content/player/348129.html', 'https://www.espncricinfo.com/newzealand/content/player/277912.html', 'https://www.espncricinfo.com/england/content/player/646847.html', 'https://www.espncricinfo.com/Ireland/content/player/470917.html', 'https://www.espncricinfo.com/Nepal/content/player/701215.html', 'https://www.espncricinfo.com/pakistan/content/player/697279.html', 'https://www.espncricinfo.com/ Kenya/content/player/24705.html', 'https://www.espncricinfo.com ...

# %%
for i in li:
      get_data(i)

# %%
df_Batting=df_Batting.drop(df_Batting.columns[0],axis=1)

df_Batting

# %%
len(li)
